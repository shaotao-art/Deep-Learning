# %%
from utils import *

# %%
x = torch.randn((32, 1, 64, 64))

# %%
plot_img_tensor(x)

# %%
v_l = [-1, 1, 10, 13, 18, 20, 31, 32]
L = 7
def slove(lst, L):
    assert len(lst) == L+1
    if L == 0:
        return 0
    else:
        return max(v_l[i] + slove(lst[:L-i+1], L-i) for i in range(1, L+1))

# %%
max(v_l)
# Out:
# 32

# %%
slove(v_l, 7)
# Out:
# 33

# %%
def slove(lst, L):
    memo = [-1 for i in range(L)]
    memo[0] = 0
    for i in range()
